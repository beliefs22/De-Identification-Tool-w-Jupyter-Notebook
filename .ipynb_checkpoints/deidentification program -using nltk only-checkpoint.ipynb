# %% [raw]
# I'm hoping that I can use this notebook to better organize my thoughts while coding.
#
# I'm buidling a de-identification program. The goals is for the program to identify PHI in a document and redact that word. This will be used to help deidentify documents automatically. The goal would be for it to be "trained" on a subset of the data so the user can identify ambigiuos words that should be allowed like study ids (eventually we will allow the user to ignore rows that it knows are fine). Then the program can be run on all the records and it will hopefully find mostly words that should be redacted not ambigious words.

# %%
#part one is to make functions to pull text from different types of files (txt, csv, .xlsx)

def getTextFile(textfile):
    """yield lines in the text file
    
    Args:
        textfile (path): path to the text file
    
    Yiedls: the lines in the text file with the newline character removed"""
    with open(textfile,'rb') as thefile:
        for line in thefile:
            
            yield line.strip("\n")


def getCSVFile(csvfile):
    """yield rows in the csv file
    
    Args:
        textfile (path): path to the file
    
    Yiedls: the rows in the file"""
    import csv

    with open(csvfile, 'rb') as thefile:
        csvreader = csv.reader(thefile)
        for row in csvreader:
            
            yield row


def getExcelFile(excelfile):
    """yield rows in the excel file
    
    Args:
        textfile (path): path to the file
    
    Yiedls: the rows in the file """
    import openpyxl
    
    wb = openpyxl.load_workbook(excelfile)
    sheet = wb.active
    
    for row in sheet.iter_rows():
        data = [str(cell.value) for cell in row]        
        yield data

a = getExcelFile('test.xlsx')
b = getCSVFile('A_test_csv.csv')
c = getTextFile('metadata.txt')

# %% [raw]
# Next Step is to create a program that takes in the text exposed from the file and parses that text into words.

# %%
import re

def getWords(text):
    """Returns list of words in the string of text"""
    splitpattern = re.compile(r"[^\w^']")
    words = splitpattern.split(text)
    for word in words:
        if word != "":
            yield word

# %% [raw]
# Next step is to create a program that determines if a given word is a Name, A medical word, An english word, or an indeterminate word (due to spelling or belonging to multiple categories)

# %%
import pickle
    
english_words = pickle.load(open('englishwordslist.p','rb'))
medical_words = pickle.load(open('medicalwordlist.p','rb'))
first_names = pickle.load(open('firstnameslist.p'))
last_names = pickle.load(open('lastnameslist.p'))

all_words = {key:value
             for dictionary in [english_words, medical_words]
             for key,value in dictionary.iteritems()}

all_names = {key:value
            for dictionary in [first_names, last_names]
            for key,value in dictionary.iteritems()}

# %%
import nltk
def categorizeWord(word):
    print "categorizing", word, nltk.pos_tag([word])
    original_word = word[:]
    word = word.lower().strip()
    
    if word.isdigit():
        return 'allowed'
    allowed = is_allowed(word)
    prohibited = is_prohibited(word)
    # both false
    if allowed == True and prohibited == True or allowed == False and prohibited == False:
        pos = nltk.pos_tag([original_word.strip()])
        if pos[0][1] == "NNP":
            return 'prohibited'
        else:
            return 'allowed'
    
    if allowed == True:
        return 'allowed'
    
    if prohibited == True:
        return 'prohibited'


def is_allowed(word):
    return word in all_words

def is_prohibited(word):
    return word in all_names

def removeDates(text):
    date_pattern = re.compile(r'([\d]{2,4}[-/][\d]{1,2}[-/][\d]{1,2})(\b)|([0-9]{1,2}[-/][\d]{1,2}[-/][\d]{2,4})(\b)')
    found_dates = date_pattern.findall(text)
    modified_text= date_pattern.sub('[REDACTED][date]', text, count=1)
    return modified_text

# %% [raw]
# Now we need to return modified text to be used to build the files

# %%
def modifyText(text):
    words = getWords(text)
    modified_text = text[:]
    for word in words:
        category = categorizeWord(word)
        if category == 'allowed':
            pass
        if category == 'prohibited':
            modified_text = modified_text.replace(word,"[REDACTED][word]")
        if category == 'indeterminate':
            modified_text = modified_text.replace(word, "[IDETERMINATE][" + word  + "]")
    return modified_text

# %% [raw]
# Now we need to write programs to build the files

# %%
import os
import csv
import openpyxl

def makeTextFile(lines,filename):
    
    print "Writing text to path", os.getcwd() + "/" + filename
    with open(filename, 'wb') as output:
        for line in lines:
            output.write(line + "\n")
    print "Finished"
            

def makeCSVFile(rows,filename):
    print "Writing data to path", os.getcwd() + "/" + filename
    with open(filename,'wb') as output:
        csvwriter = csv.writer(output)
        for row in rows:
            csvwriter.writerow(row)
    print "Finished"

def makeExcelFile(rows, filename):
    print "Writing data to path", os.getcwd() + "/" + filename    
    wb = openpyxl.workbook.Workbook()
    sheet = wb.active
    for rownum, row in enumerate(rows):
        for colnum in range(1,len(row)+1):
            sheet.cell(row=rownum+1, column=colnum+1).value = row[colnum-1]
    wb.save(filename)
    print "Finished"

new_rows = []
outcsv = 'output.csv'
for row in b:
    one_row = []
    for text in row:
        new_text = removeDates(text)
        new_text = modifyText(new_text)
        one_row.append(new_text)
    new_rows.append(one_row)
    
makeCSVFile(new_rows, outcsv)

##new_rows = []
##for row in a:
##    one_row = []
##    for text in row:
##        new_text = removeDates(text)
##        new_text = modifyText(new_text)
##        one_row.append(new_text)
##    new_rows.append(one_row)
##    
##outexcel = 'output.xlsx'    
##makeExcelFile(new_rows, outexcel)
##
##new_lines = []
##outtext = 'output.txt'
##for line in c:
##    line = removeDates(line)
##    new_lines.append(modifyText(line))
##makeTextFile(new_lines,outtext)
##
##print "done"
# Out:
# categorizing SampleIDwithtype [('SampleIDwithtype', 'NN')]
# categorizing Fname [('Fname', 'NN')]
# categorizing Lname [('Lname', 'NN')]
# categorizing DOB [('DOB', 'NN')]
# categorizing Organism [('Organism', 'NN')]
# categorizing Resistance [('Resistance', 'NN')]
# categorizing SuspectedPneumonia [('SuspectedPneumonia', 'NN')]
# categorizing onVentattimeofsamplecollection [('onVentattimeofsamplecollection', 'NN')]
# categorizing InICUattimeofsamplecollection [('InICUattimeofsamplecollection', 'NN')]
# categorizing Age [('Age', 'NN')]
# categorizing Race [('Race', 'NN')]
# categorizing Gender [('Gender', 'NN')]
# categorizing ClinicalsignsofHAP [('ClinicalsignsofHAP', 'NN')]
# categorizing VAP [('VAP', 'NN')]
# categorizing HCAP [('HCAP', 'NN')]
# categorizing HAP [('HAP', 'NN')]
# categorizing HCAP [('HCAP', 'NN')]
# categorizing VAP [('VAP', 'NN')]
# categorizing WBC [('WBC', 'NN')]
# categorizing Hematocrit [('Hematocrit', 'NN')]
# categorizing PlateletCount [('PlateletCount', 'NN')]
# categorizing Potassium [('Potassium', 'NN')]
# categorizing Creatinine [('Creatinine', 'NN')]
# categorizing TotalBilirubin [('TotalBilirubin', 'NN')]
# categorizing Lactate [('Lactate', 'NN')]
# categorizing Procalcitonin [('Procalcitonin', 'NN')]
# categorizing C [('C', 'SYM')]
# categorizing reactiveProtein [('reactiveProtein', 'NN')]
# categorizing PaO2 [('PaO2', 'NN')]
# categorizing FiO2 [('FiO2', 'NN')]
# categorizing Temperature [('Temperature', 'NN')]
# categorizing RespiratoryRate [('RespiratoryRate', 'NN')]
# categorizing BloodPressure [('BloodPressure', 'NN')]
# categorizing HR [('HR', 'NN')]
# categorizing GCS [('GCS', 'NN')]
# categorizing CryptococcusAntigen [('CryptococcusAntigen', 'NN')]
# categorizing CoccidioidesAbIgg [('CoccidioidesAbIgg', 'NN')]
# categorizing StrepPneumoUrAgn [('StrepPneumoUrAgn', 'NN')]
# categorizing Cough [('Cough', 'NN')]
# categorizing Sputum [('Sputum', 'NN')]
# categorizing Dyspnea [('Dyspnea', 'NN')]
# categorizing Admitted [('Admitted', 'VBN')]
# categorizing Admissionlocation [('Admissionlocation', 'NN')]
# categorizing Workinginpatientdiagnosis [('Workinginpatientdiagnosis', 'NN')]
# categorizing Antibioticsgivenpreculture [('Antibioticsgivenpreculture', 'NN')]
# categorizing Otherantibioticsgivenpostcultureresults [('Otherantibioticsgivenpostcultureresults', 'NNS')]
# categorizing Antibioticsprescribedondischarged [('Antibioticsprescribedondischarged', 'VBN')]
# categorizing CultureType1 [('CultureType1', 'NN')]
# categorizing CultureDate1 [('CultureDate1', 'NN')]
# categorizing Cultureresult1 [('Cultureresult1', 'NN')]
# categorizing CultureType2 [('CultureType2', 'NN')]
# categorizing CultureDate2 [('CultureDate2', 'NN')]
# categorizing Cultureresult2 [('Cultureresult2', 'NN')]
# categorizing CultureType3 [('CultureType3', 'NN')]
# categorizing CultureDate3 [('CultureDate3', 'NN')]
# categorizing Cultureresult3 [('Cultureresult3', 'NN')]
# categorizing CultureType4 [('CultureType4', 'NN')]
# categorizing CultureDate4 [('CultureDate4', 'NN')]
# categorizing Cultureresult4 [('Cultureresult4', 'NN')]
# categorizing Radiographicscantype1 [('Radiographicscantype1', 'NN')]
# categorizing RadiographicScanDate1 [('RadiographicScanDate1', 'NN')]
# categorizing Radiographiimpression1 [('Radiographiimpression1', 'NN')]
# categorizing Category1 [('Category1', 'NN')]
# categorizing Radiographicscantype2 [('Radiographicscantype2', 'NN')]
# categorizing RadiographicScanDate2 [('RadiographicScanDate2', 'NN')]
# categorizing Radiographiimpression2 [('Radiographiimpression2', 'NN')]
# categorizing Category2 [('Category2', 'NN')]
# categorizing Radiographicscantype3 [('Radiographicscantype3', 'NN')]
# categorizing RadiographicScanDate3 [('RadiographicScanDate3', 'NN')]
# categorizing Radiographiimpression3 [('Radiographiimpression3', 'NN')]
# categorizing Category3 [('Category3', 'NN')]
# categorizing ETA294 [('ETA294', 'NN')]
# categorizing Lars [('Lars', 'NNS')]
# categorizing Durham [('Durham', 'NN')]
# categorizing Sanders [('Sanders', 'NNS')]
# categorizing REDACTED [('REDACTED', 'NN')]
# categorizing date [('date', 'NN')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Stain [('Stain', 'NN')]
# categorizing Good [('Good', 'JJ')]
# categorizing REDACTED [('REDACTED', 'NN')]
# categorizing date [('date', 'NN')]
# categorizing specimen [('specimen', 'NNS')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Polymorphonuclear [('Polymorphonuclear', 'VB')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing and [('and', 'CC')]
# categorizing No [('No', 'DT')]
# categorizing Squamous [('Squamous', 'JJ')]
# categorizing Epithelial [('Epithelial', 'JJ')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing Very [('Very', 'RB')]
# categorizing light [('light', 'NN')]
# categorizing Normal [('Normal', 'JJ')]
# categorizing Upper [('Upper', 'IN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Flora [('Flora', 'NNS')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing Light [('Light', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing second [('second', 'JJ')]
# categorizing morphology [('morphology', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefazolin [('Cefazolin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefoxitin [('Cefoxitin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftriaxone [('Ceftriaxone', 'NN')]
# categorizing 32 [('32', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ertapenem [('Ertapenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing u [('u', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 3 [('3', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing 64 [('64', 'CD')]
# categorizing B [('B', 'NN')]
# categorizing M [('M', 'NN')]
# categorizing treated [('treated', 'VBN')]
# categorizing for [('for', 'IN')]
# categorizing VAP [('VAP', 'NN')]
# categorizing per [('per', 'IN')]
# categorizing notes [('notes', 'NNS')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing 14 [('14', 'CD')]
# categorizing 54 [('54', 'CD')]
# categorizing 24 [('24', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing 188 [('188', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing 1 [('1', 'CD')]
# categorizing 2 [('2', 'CD')]
# categorizing 3 [('3', 'CD')]
# categorizing 2 [('2', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 1 [('1', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing 72 [('72', 'CD')]
# categorizing 40 [('40', 'CD')]
# categorizing 37 [('37', 'CD')]
# categorizing 6 [('6', 'CD')]
# categorizing 31 [('31', 'CD')]
# categorizing 106 [('106', 'CD')]
# categorizing 62 [('62', 'CD')]
# categorizing 90 [('90', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing SICU [('SICU', 'NN')]
# categorizing VAP [('VAP', 'NN')]
# categorizing Fluconazole [('Fluconazole', 'NN')]
# categorizing 13 [('13', 'CD')]
# categorizing days [('days', 'NNS')]
# categorizing vancomycin [('vancomycin', 'NN')]
# categorizing 3 [('3', 'CD')]
# categorizing days [('days', 'NNS')]
# categorizing zosyn [('zosyn', 'NN')]
# categorizing 13 [('13', 'CD')]
# categorizing days [('days', 'NNS')]
# categorizing cipro [('cipro', 'NN')]
# categorizing 6 [('6', 'CD')]
# categorizing days [('days', 'NNS')]
# categorizing none [('none', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 7 [('7', 'CD')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Stain [('Stain', 'NN')]
# categorizing Heavy [('Heavy', 'NNP')]
# categorizing Polymorphonuclear [('Polymorphonuclear', 'VB')]
# categorizing Leukocytes [('Leukocytes', 'NNS')]
# categorizing No [('No', 'DT')]
# categorizing squamous [('squamous', 'JJ')]
# categorizing epithelial [('epithelial', 'JJ')]
# categorizing cells [('cells', 'NNS')]
# categorizing No [('No', 'DT')]
# categorizing organisms [('organisms', 'NNS')]
# categorizing seen [('seen', 'VBN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing 3000 [('3000', 'CD')]
# categorizing CFU [('CFU', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing 2000 [('2000', 'CD')]
# categorizing CFU [('CFU', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing second [('second', 'JJ')]
# categorizing morphology [('morphology', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing VC [('VC', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 10 [('10', 'CD')]
# categorizing 000 [('000', 'CD')]
# categorizing CFU [('CFU', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 10 [('10', 'CD')]
# categorizing 000 [('000', 'CD')]
# categorizing CFU [('CFU', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing second [('second', 'JJ')]
# categorizing morphology [('morphology', 'NN')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Stenotrophomonas [('Stenotrophomonas', 'NNS')]
# categorizing maltophilia [('maltophilia', 'NNS')]
# categorizing 4000 [('4000', 'CD')]
# categorizing CFU [('CFU', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing Sulbactam [('Sulbactam', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefazolin [('Cefazolin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefoxitin [('Cefoxitin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftriaxone [('Ceftriaxone', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ertapenem [('Ertapenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 25 [('25', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing u [('u', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Enterobacter [('Enterobacter', 'NN')]
# categorizing cloacae [('cloacae', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing Sulbactam [('Sulbactam', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefazolin [('Cefazolin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefoxitin [('Cefoxitin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftriaxone [('Ceftriaxone', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ertapenem [('Ertapenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 25 [('25', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing u [('u', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 3 [('3', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Stenotrophomonas [('Stenotrophomonas', 'NNS')]
# categorizing maltophilia [('maltophilia', 'NNS')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing u [('u', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing xray [('xray', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 7 [('7', 'CD')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing single [('single', 'JJ')]
# categorizing view [('view', 'NN')]
# categorizing Interval [('Interval', 'NN')]
# categorizing placement [('placement', 'NN')]
# categorizing of [('of', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing nasal [('nasal', 'NN')]
# categorizing duodenostomy [('duodenostomy', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing that [('that', 'IN')]
# categorizing is [('is', 'VBZ')]
# categorizing seen [('seen', 'VBN')]
# categorizing within [('within', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing cervical [('cervical', 'JJ')]
# categorizing esophagus [('esophagus', 'NN')]
# categorizing at [('at', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing thoracic [('thoracic', 'NN')]
# categorizing inlet [('inlet', 'NN')]
# categorizing Endotracheal [('Endotracheal', 'NN')]
# categorizing and [('and', 'CC')]
# categorizing enteric [('enteric', 'NN')]
# categorizing tubes [('tubes', 'NNS')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing Left [('Left', 'VBN')]
# categorizing subclavian [('subclavian', 'JJ')]
# categorizing central [('central', 'JJ')]
# categorizing line [('line', 'NN')]
# categorizing is [('is', 'VBZ')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing at [('at', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing mid [('mid', 'NN')]
# categorizing to [('to', 'TO')]
# categorizing upper [('upper', 'JJ')]
# categorizing superior [('superior', 'JJ')]
# categorizing vena [('vena', 'NN')]
# categorizing cava [('cava', 'NN')]
# categorizing Bilateral [('Bilateral', 'JJ')]
# categorizing thoracostomy [('thoracostomy', 'NN')]
# categorizing tubes [('tubes', 'NNS')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing The [('The', 'DT')]
# categorizing cardiac [('cardiac', 'NN')]
# categorizing silhouette [('silhouette', 'NN')]
# categorizing is [('is', 'VBZ')]
# categorizing normal [('normal', 'JJ')]
# categorizing The [('The', 'DT')]
# categorizing thoracic [('thoracic', 'NN')]
# categorizing aorta [('aorta', 'NN')]
# categorizing is [('is', 'VBZ')]
# categorizing tortuous [('tortuous', 'JJ')]
# categorizing Stable [('Stable', 'JJ')]
# categorizing right [('right', 'NN')]
# categorizing basilar [('basilar', 'NN')]
# categorizing hazy [('hazy', 'NN')]
# categorizing opacity [('opacity', 'NN')]
# categorizing from [('from', 'IN')]
# categorizing pulmonary [('pulmonary', 'JJ')]
# categorizing contusion [('contusion', 'NN')]
# categorizing Multiple [('Multiple', 'NN')]
# categorizing right [('right', 'NN')]
# categorizing sided [('sided', 'VBD')]
# categorizing rib [('rib', 'NN')]
# categorizing fractures [('fractures', 'NNS')]
# categorizing and [('and', 'CC')]
# categorizing subcutaneous [('subcutaneous', 'JJ')]
# categorizing emphysema [('emphysema', 'NN')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing see [('see', 'VB')]
# categorizing impression [('impression', 'NN')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing xray [('xray', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing Bilateral [('Bilateral', 'JJ')]
# categorizing chest [('chest', 'NN')]
# categorizing tubes [('tubes', 'NNS')]
# categorizing endotracheal [('endotracheal', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing enteric [('enteric', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing and [('and', 'CC')]
# categorizing left [('left', 'NN')]
# categorizing approach [('approach', 'NN')]
# categorizing PICC [('PICC', 'NN')]
# categorizing positions [('positions', 'NNS')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing Bilateral [('Bilateral', 'JJ')]
# categorizing upper [('upper', 'JJ')]
# categorizing lobe [('lobe', 'NN')]
# categorizing emphysematous [('emphysematous', 'JJ')]
# categorizing changes [('changes', 'NNS')]
# categorizing Probable [('Probable', 'JJ')]
# categorizing tiny [('tiny', 'JJ')]
# categorizing right [('right', 'NN')]
# categorizing pleural [('pleural', 'JJ')]
# categorizing effusion [('effusion', 'NN')]
# categorizing and [('and', 'CC')]
# categorizing new [('new', 'JJ')]
# categorizing patchy [('patchy', 'NN')]
# categorizing right [('right', 'NN')]
# categorizing basal [('basal', 'NN')]
# categorizing airspace [('airspace', 'NN')]
# categorizing disease [('disease', 'NN')]
# categorizing New [('New', 'NNP')]
# categorizing opacity [('opacity', 'NN')]
# categorizing in [('in', 'IN')]
# categorizing left [('left', 'NN')]
# categorizing lower [('lower', 'JJR')]
# categorizing lobe [('lobe', 'NN')]
# categorizing near [('near', 'IN')]
# categorizing costophrenic [('costophrenic', 'NN')]
# categorizing angle [('angle', 'NN')]
# categorizing Unchanged [('Unchanged', 'VBN')]
# categorizing cardiomediastinal [('cardiomediastinal', 'NN')]
# categorizing silhouette [('silhouette', 'NN')]
# categorizing Multiple [('Multiple', 'NN')]
# categorizing displaced [('displaced', 'VBN')]
# categorizing right [('right', 'NN')]
# categorizing rib [('rib', 'NN')]
# categorizing fractures [('fractures', 'NNS')]
# categorizing see [('see', 'VB')]
# categorizing impression [('impression', 'NN')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing ct [('ct', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 7 [('7', 'CD')]
# categorizing Significantly [('Significantly', 'RB')]
# categorizing enlarged [('enlarged', 'VBN')]
# categorizing extrapleural [('extrapleural', 'JJ')]
# categorizing heterogenous [('heterogenous', 'JJ')]
# categorizing collection [('collection', 'NN')]
# categorizing within [('within', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing right [('right', 'NN')]
# categorizing hemithorax [('hemithorax', 'NN')]
# categorizing resulting [('resulting', 'VBG')]
# categorizing in [('in', 'IN')]
# categorizing mediastinal [('mediastinal', 'NN')]
# categorizing shift [('shift', 'NN')]
# categorizing Given [('Given', 'VBN')]
# categorizing the [('the', 'DT')]
# categorizing clinical [('clinical', 'JJ')]
# categorizing history [('history', 'NN')]
# categorizing appearances [('appearances', 'NNS')]
# categorizing are [('are', 'VBP')]
# categorizing concerning [('concerning', 'VBG')]
# categorizing for [('for', 'IN')]
# categorizing interval [('interval', 'NN')]
# categorizing hemorrhage [('hemorrhage', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing Left [('Left', 'VBN')]
# categorizing hydropneumothorax [('hydropneumothorax', 'NN')]
# categorizing has [('has', 'VBZ')]
# categorizing decreased [('decreased', 'VBN')]
# categorizing in [('in', 'IN')]
# categorizing size [('size', 'NN')]
# categorizing 3 [('3', 'CD')]
# categorizing Remaining [('Remaining', 'VBG')]
# categorizing additional [('additional', 'JJ')]
# categorizing findings [('findings', 'NNS')]
# categorizing including [('including', 'VBG')]
# categorizing multiple [('multiple', 'NN')]
# categorizing fractures [('fractures', 'NNS')]
# categorizing right [('right', 'NN')]
# categorizing renal [('renal', 'NN')]
# categorizing calculus [('calculus', 'NN')]
# categorizing and [('and', 'CC')]
# categorizing bilateral [('bilateral', 'JJ')]
# categorizing hyperattenuating [('hyperattenuating', 'VBG')]
# categorizing renal [('renal', 'NN')]
# categorizing lesions [('lesions', 'NNS')]
# categorizing as [('as', 'IN')]
# categorizing described [('described', 'NN')]
# categorizing see [('see', 'VB')]
# categorizing impression [('impression', 'NN')]
# categorizing ETA295 [('ETA295', 'NN')]
# categorizing Quentin [('Quentin', 'NN')]
# categorizing Mcclure [('Mcclure', 'NN')]
# categorizing Walton [('Walton', 'NNP')]
# categorizing REDACTED [('REDACTED', 'NN')]
# categorizing date [('date', 'NN')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Stain [('Stain', 'NN')]
# categorizing Adequate [('Adequate', 'NN')]
# categorizing specimen [('specimen', 'NNS')]
# categorizing Light [('Light', 'NN')]
# categorizing Polymorphonuclear [('Polymorphonuclear', 'VB')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing and [('and', 'CC')]
# categorizing Very [('Very', 'RB')]
# categorizing Light [('Light', 'NN')]
# categorizing Squamous [('Squamous', 'JJ')]
# categorizing Epithelial [('Epithelial', 'JJ')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing Heavy [('Heavy', 'NNP')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Negative [('Negative', 'JJ')]
# categorizing Bacilli [('Bacilli', 'NNP')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Normal [('Normal', 'JJ')]
# categorizing Upper [('Upper', 'IN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Flora [('Flora', 'NNS')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Flora [('Flora', 'NNS')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Serratia [('Serratia', 'NN')]
# categorizing marcescens [('marcescens', 'NNS')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing HH [('HH', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Culture [('Culture', 'NN')]
# categorizing Stenotrophomonas [('Stenotrophomonas', 'NNS')]
# categorizing maltophilia [('maltophilia', 'NNS')]
# categorizing Heavy [('Heavy', 'NNP')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Serratia [('Serratia', 'NN')]
# categorizing marcescens [('marcescens', 'NNS')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing Sulbactam [('Sulbactam', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefazolin [('Cefazolin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefoxitin [('Cefoxitin', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftriaxone [('Ceftriaxone', 'NN')]
# categorizing 32 [('32', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 32 [('32', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ertapenem [('Ertapenem', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 64 [('64', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Pseudomonas [('Pseudomonas', 'NNS')]
# categorizing aeruginosa [('aeruginosa', 'NN')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing 8 [('8', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Stenotrophomonas [('Stenotrophomonas', 'NNS')]
# categorizing maltophilia [('maltophilia', 'NNS')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing 16 [('16', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing 38 [('38', 'CD')]
# categorizing ug [('ug', 'NN')]
# categorizing mL [('mL', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing treatment [('treatment', 'NN')]
# categorizing for [('for', 'IN')]
# categorizing pneumonia [('pneumonia', 'NN')]
# categorizing conclududed [('conclududed', 'VBN')]
# categorizing more [('more', 'RBR')]
# categorizing than [('than', 'IN')]
# categorizing 1 [('1', 'CD')]
# categorizing week [('week', 'NN')]
# categorizing before [('before', 'IN')]
# categorizing sample [('sample', 'NN')]
# categorizing collection [('collection', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing trach [('trach', 'NN')]
# categorizing collar [('collar', 'NN')]
# categorizing yes [('yes', 'NNS')]
# categorizing 19 [('19', 'CD')]
# categorizing B [('B', 'NN')]
# categorizing F [('F', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing 50 [('50', 'CD')]
# categorizing 36 [('36', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing 33 [('33', 'CD')]
# categorizing 125 [('125', 'CD')]
# categorizing 59 [('59', 'CD')]
# categorizing 100 [('100', 'CD')]
# categorizing 15 [('15', 'CD')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing Peds [('Peds', 'NNS')]
# categorizing ICU [('ICU', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing id [('id', 'NN')]
# categorizing diagnosis [('diagnosis', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# ...
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing ETA322 [('ETA322', 'NN')]
# categorizing Lucian [('Lucian', 'JJ')]
# categorizing Pacheco [('Pacheco', 'NN')]
# categorizing Underwood [('Underwood', 'NN')]
# categorizing REDACTED [('REDACTED', 'NN')]
# categorizing date [('date', 'NN')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Stain [('Stain', 'NN')]
# categorizing Good [('Good', 'JJ')]
# categorizing specimen [('specimen', 'NNS')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Polymorphonuclear [('Polymorphonuclear', 'VB')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing and [('and', 'CC')]
# categorizing Very [('Very', 'RB')]
# categorizing Light [('Light', 'NN')]
# categorizing Squamous [('Squamous', 'JJ')]
# categorizing Epithelial [('Epithelial', 'JJ')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Negative [('Negative', 'JJ')]
# categorizing Diplococci [('Diplococci', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Cult [('Cult', 'NN')]
# categorizing Positive [('Positive', 'JJ')]
# categorizing ORG [('ORG', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Klebsiella [('Klebsiella', 'NN')]
# categorizing pneumoniae [('pneumoniae', 'NN')]
# categorizing ORG [('ORG', 'NN')]
# categorizing 2 [('2', 'CD')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Acinetobacter [('Acinetobacter', 'NN')]
# categorizing baumannii [('baumannii', 'NN')]
# categorizing calcoaceticus [('calcoaceticus', 'NN')]
# categorizing complex [('complex', 'JJ')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Cult [('Cult', 'NN')]
# categorizing Klebsiella [('Klebsiella', 'NN')]
# categorizing pneumoniae [('pneumoniae', 'NN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Cult [('Cult', 'NN')]
# categorizing Acinetobacter [('Acinetobacter', 'NN')]
# categorizing bauman [('bauman', 'NN')]
# categorizing calc [('calc', 'NN')]
# categorizing cplx [('cplx', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Klebsiella [('Klebsiella', 'NN')]
# categorizing pneumoniae [('pneumoniae', 'NN')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing Sulbactam [('Sulbactam', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing R [('R', 'NN')]
# categorizing Cefazolin [('Cefazolin', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Cefoxitin [('Cefoxitin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ceftriaxone [('Ceftriaxone', 'NN')]
# categorizing R [('R', 'NN')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Ertapenem [('Ertapenem', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Piperacillin [('Piperacillin', 'NN')]
# categorizing Tazobactam [('Tazobactam', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Susceptibility [('Susceptibility', 'NN')]
# categorizing Acinetobacter [('Acinetobacter', 'NN')]
# categorizing bauman [('bauman', 'NN')]
# categorizing calc [('calc', 'NN')]
# categorizing cplx [('cplx', 'NN')]
# categorizing MIC [('MIC', 'NN')]
# categorizing Amikacin [('Amikacin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ampicillin [('Ampicillin', 'NN')]
# categorizing Sulbactam [('Sulbactam', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Aztreonam [('Aztreonam', 'NNP')]
# categorizing R [('R', 'NN')]
# categorizing Cefepime [('Cefepime', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Ceftazidime [('Ceftazidime', 'NN')]
# categorizing I [('I', 'PRP')]
# categorizing Ciprofloxacin [('Ciprofloxacin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Gentamicin [('Gentamicin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Meropenem [('Meropenem', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tetracycline [('Tetracycline', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Tobramycin [('Tobramycin', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing Trimethoprim [('Trimethoprim', 'NN')]
# categorizing Sulfamethoxazole [('Sulfamethoxazole', 'NN')]
# categorizing S [('S', 'NN')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing 38 [('38', 'CD')]
# categorizing O [('O', 'NN')]
# categorizing F [('F', 'NN')]
# categorizing concern [('concern', 'NN')]
# categorizing for [('for', 'IN')]
# categorizing tracheitis [('tracheitis', 'NN')]
# categorizing vs [('vs', 'NN')]
# categorizing VAP [('VAP', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing 10 [('10', 'CD')]
# categorizing 58 [('58', 'CD')]
# categorizing 37 [('37', 'CD')]
# categorizing 8 [('8', 'CD')]
# categorizing 301 [('301', 'CD')]
# categorizing 3 [('3', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing 0 [('0', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 0 [('0', 'CD')]
# categorizing 5 [('5', 'CD')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing 40 [('40', 'CD')]
# categorizing 36 [('36', 'CD')]
# categorizing 9 [('9', 'CD')]
# categorizing 20 [('20', 'CD')]
# categorizing 113 [('113', 'CD')]
# categorizing 79 [('79', 'CD')]
# categorizing 91 [('91', 'CD')]
# categorizing unclear [('unclear', 'JJ')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing PCU [('PCU', 'NN')]
# categorizing pneumonia [('pneumonia', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing xray [('xray', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing There [('There', 'EX')]
# categorizing is [('is', 'VBZ')]
# categorizing mild [('mild', 'NN')]
# categorizing atelectasis [('atelectasis', 'NN')]
# categorizing at [('at', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing left [('left', 'NN')]
# categorizing lung [('lung', 'NN')]
# categorizing base [('base', 'NN')]
# categorizing No [('No', 'DT')]
# categorizing definite [('definite', 'NN')]
# categorizing evidence [('evidence', 'NN')]
# categorizing of [('of', 'IN')]
# categorizing pneumonia [('pneumonia', 'NN')]
# categorizing or [('or', 'CC')]
# categorizing focal [('focal', 'JJ')]
# categorizing consolidation [('consolidation', 'NN')]
# categorizing Improved [('Improved', 'VBN')]
# categorizing aeration [('aeration', 'NN')]
# categorizing of [('of', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing lungs [('lungs', 'NNS')]
# categorizing since [('since', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing prior [('prior', 'RB')]
# categorizing study [('study', 'NN')]
# categorizing Top [('Top', 'JJ')]
# categorizing normal [('normal', 'JJ')]
# categorizing sized [('sized', 'VBN')]
# categorizing heart [('heart', 'NN')]
# categorizing No [('No', 'DT')]
# categorizing acute [('acute', 'NN')]
# categorizing pulmonary [('pulmonary', 'JJ')]
# categorizing edema [('edema', 'NN')]
# categorizing Tracheostomy [('Tracheostomy', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing atelectasis [('atelectasis', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing ETA323 [('ETA323', 'NN')]
# categorizing Hyatt [('Hyatt', 'NN')]
# categorizing Huber [('Huber', 'NNP')]
# categorizing Ferguson [('Ferguson', 'NN')]
# categorizing REDACTED [('REDACTED', 'NN')]
# categorizing date [('date', 'NN')]
# categorizing Gram [('Gram', 'NN')]
# categorizing Stain [('Stain', 'NN')]
# categorizing Good [('Good', 'JJ')]
# categorizing specimen [('specimen', 'NNS')]
# categorizing Moderate [('Moderate', 'JJ')]
# categorizing Polymorphonuclear [('Polymorphonuclear', 'VB')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing and [('and', 'CC')]
# categorizing Very [('Very', 'RB')]
# categorizing Light [('Light', 'NN')]
# categorizing Squamous [('Squamous', 'JJ')]
# categorizing Epithelial [('Epithelial', 'JJ')]
# categorizing Cells [('Cells', 'NNS')]
# categorizing Heavy [('Heavy', 'NNP')]
# categorizing Normal [('Normal', 'JJ')]
# categorizing Upper [('Upper', 'IN')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Flora [('Flora', 'NNS')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Cult [('Cult', 'NN')]
# categorizing Heavy [('Heavy', 'NNP')]
# categorizing Respiratory [('Respiratory', 'NN')]
# categorizing Flora [('Flora', 'NNS')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing 60 [('60', 'CD')]
# categorizing W [('W', 'NN')]
# categorizing M [('M', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing 6 [('6', 'CD')]
# categorizing 59 [('59', 'CD')]
# categorizing 32 [('32', 'CD')]
# categorizing 6 [('6', 'CD')]
# categorizing 77 [('77', 'CD')]
# categorizing 4 [('4', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing 2 [('2', 'CD')]
# categorizing 6 [('6', 'CD')]
# categorizing 0 [('0', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing 102 [('102', 'CD')]
# categorizing 40 [('40', 'CD')]
# categorizing 37 [('37', 'CD')]
# categorizing 7 [('7', 'CD')]
# categorizing 20 [('20', 'CD')]
# categorizing unclear [('unclear', 'JJ')]
# categorizing 132 [('132', 'CD')]
# categorizing unclear [('unclear', 'JJ')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing no [('no', 'DT')]
# categorizing yes [('yes', 'NNS')]
# categorizing yes [('yes', 'NNS')]
# categorizing Burn [('Burn', 'NN')]
# categorizing ICU [('ICU', 'NN')]
# categorizing unclear [('unclear', 'JJ')]
# categorizing id [('id', 'NN')]
# categorizing diagnosis [('diagnosis', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing vancomycin [('vancomycin', 'NN')]
# categorizing 1 [('1', 'CD')]
# categorizing day [('day', 'NN')]
# categorizing none [('none', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing xray [('xray', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 0 [('0', 'CD')]
# categorizing Endotracheal [('Endotracheal', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing appears [('appears', 'VBZ')]
# categorizing advanced [('advanced', 'JJ')]
# categorizing slightly [('slightly', 'RB')]
# categorizing since [('since', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing prior [('prior', 'RB')]
# categorizing study [('study', 'NN')]
# categorizing with [('with', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing tip [('tip', 'NN')]
# categorizing now [('now', 'RB')]
# categorizing at [('at', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing carina [('carina', 'NN')]
# categorizing and [('and', 'CC')]
# categorizing possibly [('possibly', 'RB')]
# categorizing within [('within', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing proximal [('proximal', 'NN')]
# categorizing right [('right', 'NN')]
# categorizing mainstem [('mainstem', 'NN')]
# categorizing bronchus [('bronchus', 'NN')]
# categorizing Suggest [('Suggest', 'NN')]
# categorizing withdrawing [('withdrawing', 'VBG')]
# categorizing endotracheal [('endotracheal', 'NN')]
# categorizing tube [('tube', 'NN')]
# categorizing slightly [('slightly', 'RB')]
# categorizing Otherwise [('Otherwise', 'RB')]
# categorizing no [('no', 'DT')]
# categorizing significant [('significant', 'JJ')]
# categorizing change [('change', 'NN')]
# categorizing since [('since', 'IN')]
# categorizing the [('the', 'DT')]
# categorizing prior [('prior', 'RB')]
# categorizing study [('study', 'NN')]
# categorizing see [('see', 'VB')]
# categorizing impression [('impression', 'NN')]
# categorizing Chest [('Chest', 'JJS')]
# categorizing xray [('xray', 'NN')]
# categorizing T [('T', 'NN')]
# categorizing 7 [('7', 'CD')]
# categorizing Medical [('Medical', 'JJ')]
# categorizing apparatus [('apparatus', 'NN')]
# categorizing unchanged [('unchanged', 'JJ')]
# categorizing Slight [('Slight', 'NN')]
# categorizing improvement [('improvement', 'NN')]
# categorizing in [('in', 'IN')]
# categorizing aeration [('aeration', 'NN')]
# categorizing with [('with', 'IN')]
# categorizing some [('some', 'DT')]
# categorizing minimal [('minimal', 'NN')]
# categorizing residual [('residual', 'JJ')]
# categorizing increased [('increased', 'VBN')]
# categorizing interstitial [('interstitial', 'JJ')]
# categorizing markings [('markings', 'NNS')]
# categorizing on [('on', 'IN')]
# categorizing a [('a', 'DT')]
# categorizing portable [('portable', 'JJ')]
# categorizing exam [('exam', 'NN')]
# categorizing see [('see', 'VB')]
# categorizing impression [('impression', 'NN')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# categorizing n [('n', 'NN')]
# categorizing a [('a', 'DT')]
# Writing data to path H:\mynotebooks\De-Identification Program/output.csv
# Finished
